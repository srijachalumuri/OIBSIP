# %% [markdown]
# <a href="https://colab.research.google.com/github/srijachalumuri/OIBSIP/blob/main/LEVEL_1_PROJECT_1(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATA LOADING**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# List the contents of the directory containing the CSV file
directory_contents = os.listdir('/content/sample_data/')
print(directory_contents)

# Load the CSV file
menu_df = pd.read_csv('/content/sample_data/menu.csv')

# Display the first few rows of the DataFrame
print(menu_df.head())
# Out:
# ['anscombe.json', 'README.md', 'menu.csv', 'mnist_test.csv', 'california_housing_test.csv', 'california_housing_train.csv', 'mnist_train_small.csv']
#     Category                              Item    Serving Size  Calories  Calories from Fat  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300                120
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250                 70
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370                200
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450                250
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400                210
#
#    Total Fat  Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  \
# 0       13.0                         20            5.0                             25        0.0
# ...

# %%
food=pd.read_csv('/content/sample_data/menu.csv') #importing the dataset

# %%
food #loading the dataset
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# **CLEANING OF THE DATA**

# %%
print("Dimension of the dataset:", food.shape)
print("Size of the dataset: ", food.size)
print("Columns in the dataset: ", food.keys())
# Out:
# Dimension of the dataset: (260, 24)
# Size of the dataset:  6240
# Columns in the dataset:  Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
print("Information of the dataset: \n",food.info())
print("After removing duplicates: \n",food.drop_duplicates(inplace=True))
print("Size of the dataset after removing duplicates: \n",food.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %% [markdown]
# **DESCRIPTIVE ANALYSIS**

# %%
print("Description of the dataset: \n",food.describe())
# Out:
# Description of the dataset:
#            Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# **PRODUCT ANALYSIS AND VISUALIZATION**

# %%
# Pie chart for the proportion of different categories
category_counts = food['Category'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('Proportion of Different Categories')
plt.show()

# %% [markdown]
# We can see that the majority items in the menu comprises of Coffee & Tea, followed by Breakfast, while the least items are from Salads section

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(x='Category', y='Calories', data=food)
plt.xticks(rotation=45)
plt.title('Calories by Category')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.show()

# %% [markdown]
# The product category which has an item with the highest calories is Chicken & Fish. The item is an outlier and is found out below

# %%
food['Calories'].idxmax()
# Out:
# 82

# %%
food.at[82, 'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %% [markdown]
# **The item is a 40 piece Chicken McNugget.**

# %%
food['Protein'].idxmax()
# Out:
# 82

# %% [markdown]
# **The 40 piece Chicken McNugget has the highest calories, protein,etc**

# %%
food['Cholesterol'].idxmax()
# Out:
# 31

# %%
food.at[31, 'Item']
# Out:
# 'Big Breakfast with Hotcakes (Regular Biscuit)'

# %% [markdown]
# **The food with the highest cholesterol is Big Breakfast with Hotcakes(Regular Biscuit)**

# %%
food[['Saturated Fat (% Daily Value)','Saturated Fat']].idxmax()
# Out:
# Saturated Fat (% Daily Value)    253
# Saturated Fat                     32
# dtype: int64

# %%
value_1 = food.iloc[253, 1]
value_2 = food.iloc[32, 1]
print(value_1," ", value_2)
# Out:
# McFlurry with M&M’s Candies (Medium)   Big Breakfast with Hotcakes (Large Biscuit)

# %% [markdown]
# **The foods with highest Saturated Fats are McFlurry with M&M's Candies (Medium) and Big Breakfast with Hotcakes (Large Biscuit)**

# %%
item_with_highest_calories = food.loc[food.groupby(['Category'])['Calories'].idxmax()]
item_with_highest_calories_sorted = item_with_highest_calories.sort_values(by='Calories', ascending=False)[['Category','Item', 'Calories']]
print(item_with_highest_calories_sorted)
# Out:
#                Category                                         Item  Calories
# 82       Chicken & Fish                 Chicken McNuggets (40 piece)      1880
# 32            Breakfast  Big Breakfast with Hotcakes (Large Biscuit)      1150
# 253  Smoothies & Shakes         McFlurry with M&M’s Candies (Medium)       930
# 231        Coffee & Tea                Frappé Chocolate Chip (Large)       760
# 47          Beef & Pork           Double Quarter Pounder with Cheese       750
# 98       Snacks & Sides                           Large French Fries       510
# 88               Salads  Premium Southwest Salad with Crispy Chicken       450
# 108            Desserts                           Hot Caramel Sundae       340
# 112           Beverages                    Coca-Cola Classic (Large)       280

# %% [markdown]
# **The most calorific item in the menu is Chicken McNuggets(40 piece) in Chicken & Fish category. Likewise, Big Breakfast with Hotcakes (Large Biscuit) is the most calorific item in Breakfast category and so on**

# %%
item_with_lowest_calories = food.loc[food.groupby(['Category'])['Calories'].idxmin()]
item_with_lowest_calories_sorted = item_with_lowest_calories.sort_values(by='Calories', ascending=False)[['Category','Item', 'Calories']]
print(item_with_lowest_calories_sorted)
# Out:
#                Category                                         Item  Calories
# 48          Beef & Pork                                    Hamburger       240
# 235  Smoothies & Shakes           Strawberry Banana Smoothie (Small)       210
# 78       Chicken & Fish                  Chicken McNuggets (4 piece)       190
# 38            Breakfast                                   Hash Brown       150
# 84               Salads  Premium Bacon Ranch Salad (without Chicken)       140
# 106            Desserts                          Kids Ice Cream Cone        45
# 101      Snacks & Sides                                 Apple Slices        15
# 114           Beverages                            Diet Coke (Small)         0
# 137        Coffee & Tea                             Iced Tea (Small)         0

# %% [markdown]
# **The least calorific items in the menu are Diet Coke(Small) and an Iced Tea(Small) in Beverages and Coffee & Tea categories respectively. The least calorific item in Beef & Pork is a Hamburger**

# %%
def plot_histogram(column, bins=30):
    plt.figure(figsize=(10, 6))
    sns.histplot(food[column], bins=bins, kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

columns_to_plot = ['Calories', 'Total Fat', 'Saturated Fat', 'Cholesterol', 'Sodium', 'Carbohydrates', 'Sugars', 'Protein']
for column in columns_to_plot:
    plot_histogram(column)

# %% [markdown]
# **The frequency to eat calorific foods are in an increasing order from 0 - 250 calories, then it decreases. The only outlier is at 1880 calories. Likewise, for Total Fat, it is in a decreasing order. Similarly for Carbohydrates, the frequency is increasing till 40, and then it steadily decreases**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=food['Calories'], y=food['Protein'])
plt.title('Calories vs Protein')
plt.xlabel('Calories')
plt.ylabel('Protein')
plt.show()

# %% [markdown]
# **The average human being should aim for around 56g of protein per day and daily caloric intake is around 2,000 to 2,500 calories per day for women and 2,500 to 3,000 calories per day for men. According to the graph, the more densely populated area is people who have calorie intake of 0-750 while taking protein of 0-50g.**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=food['Calories'], y=food['Total Fat'])
plt.title('Calories vs Total Fat')
plt.xlabel('Calories')
plt.ylabel('Total Fat')
plt.show()

# %% [markdown]
# **The average human being should have fat intake of 44-78 grams of fat per day. According to the graph, the most densely populated area is people who have calorie intake between 0-750 and gaining 0-50g of fat per day**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=food['Calories'], y=food['Sugars'])
plt.title('Calories vs Sugar')
plt.xlabel('Calories')
plt.ylabel('Sugar')
plt.show()

# %% [markdown]
# **The average sugar intake should be 25 grams (6 teaspoons) of added sugars per day for women and 36 grams (9 teaspoons) for men. This is based on a daily caloric intake of around 2,000 calories. According to the graph, as the number of calories increases uptil 1000, the sugar level increases till it reaches 130 at 875 calories.**

# %%
plot=sns.stripplot(x="Category", y='Sugars', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Sugar Content')
plt.show()

# %% [markdown]
# **Smoothies and Shakes have the highest sugar content out of all the food categories. Coffee & Tea is densely populated between 10-70 sugar per day.**

# %%
plot=sns.stripplot(x="Category", y='Sodium', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Sodium Content')
plt.show()

# %% [markdown]
# **Some categories, like breakfast and beef & pork, contain items with extremely high sodium content.**
#
# **Categories like beverages, coffee & tea, and smoothies & shakes have very low sodium content, making them better options for those looking to reduce their sodium intake.**

# %%
plot=sns.stripplot(x="Category", y='Protein', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Protein Content')
plt.show()

# %% [markdown]
# **The categories "Beef & Pork" and "Chicken & Fish" tend to have the highest protein content, while "Desserts", "Beverages", and "Coffee & Tea" have the lowest.**

# %%
plot=sns.stripplot(x="Category", y='Total Fat', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Total Fat Content')
plt.show()

# %% [markdown]
# **Breakfast, Beef & Pork, and Chicken & Fish are the categories with high total fat. Beverages contain least total fat.**

# %%
plot=sns.stripplot(x="Category", y='Cholesterol', data=food)
plt.setp(plot.get_xticklabels(), rotation=70)
plt.title('Cholesterol Content')
plt.show()

# %% [markdown]
# **Breakfast items have high cholesterol, while beverages have the least**

# %%
# Select only numeric columns for the correlation matrix
numeric_data = food.select_dtypes(include=['float64', 'int64'])

# Correlation Heatmap
plt.figure(figsize=(14, 10))
correlation_matrix = numeric_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Nutritional Values')
plt.show()

# %% [markdown]
# **This shows how each column is correlated to each other.**

# %%
sorted_items_by_calories = food.sort_values(by=['Category', 'Calories'], ascending=[True, False]) #Sort by Calories

# Print the sorted items by category
for category, items in sorted_items_by_calories.groupby('Category'):
    pd.set_option('display.max_rows', None)  # Show all rows
    pd.set_option('display.max_columns', None)  # Show all columns
    pd.set_option('display.width', None) #Auto-adjust width
    print(f"Category: {category}")
    print(items[['Item', 'Calories']])
    print("\n")

# Create a bar plot to show the top items with the highest calories in each category
plt.figure(figsize=(12, 6))
top_items = sorted_items_by_calories.groupby('Category').head(1)  # Select top item in each category
plt.bar(top_items['Category'], top_items['Calories'], color='skyblue')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.title('Top Item with Highest Calories in Each Category')
plt.xticks(rotation=45)
plt.show()

# Create a pie chart to show the distribution of calories among different categories
plt.figure(figsize=(8, 8))
total_calories_per_category = food.groupby('Category')['Calories'].sum()
plt.pie(total_calories_per_category, labels=total_calories_per_category.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.axis('equal')
plt.title('Calories Distribution by Category')
plt.show()
# Out:
# Category: Beef & Pork
#                                          Item  Calories
# 47         Double Quarter Pounder with Cheese       750
# 51                     Bacon Clubhouse Burger       720
# 45  Quarter Pounder with Bacon Habanero Ranch       610
# 44        Quarter Pounder with Bacon & Cheese       600
# 46                     Quarter Pounder Deluxe       540
# 42                                    Big Mac       530
# 43                Quarter Pounder with Cheese       520
# 56                                      McRib       500
# 53                             Bacon McDouble       440
# 50                        Double Cheeseburger       430
# 54                               Daily Double       430
# 55                            Jalapeño Double       430
# 52                                   McDouble       380
# 49                               Cheeseburger       290
# 48                                  Hamburger       240
#
#
# Category: Beverages
# ...

# %% [markdown]
# **By looking at the pie chart, we can see that Coffee & Tea contribute most to the highest percentage of Calories closely followed by Breakfast, then Chicken & Fish, and so on. The least calorific items are in the Salad and Dessert section.**

# %% [markdown]
# **INFERENCE -**
#
# MENU ITEMS & CALORIES:
#
# (I) We can see that the majority items in the menu comprises of Coffee & Tea, followed by Breakfast, while the least items are from Salads section.
#
# (II) The mean calories in the foods is 368 and 75% of the food has calories of 500 or below.
#
# (III) The product category which has an item with the highest calories is Chicken & Fish. The item is an outlier. The item is a 40 piece Chicken McNugget.The 40 piece Chicken McNugget has the highest calories, protein,etc.
#
# (IV) The most calorific item in the menu is Chicken McNuggets(40 piece) in Chicken & Fish category. Likewise, Big Breakfast with Hotcakes (Large Biscuit) is the most calorific item in Breakfast category and so on. The least calorific items in the menu are Diet Coke(Small) and an Iced Tea(Small) in Beverages and Coffee & Tea categories respectively.
#
# (V) The least calorific item in Beef & Pork is a Hamburger.
#
# (VI) We can see that Coffee & Tea contribute most to the highest percentage of Calories closely followed by Breakfast, then Chicken & Fish, and so on. The least calorific items are in the Salad and Dessert section.

# %% [markdown]
# **RECOMMENDATIONS:**
#
# If a customer is very conscious on his/her calories, they should avoid the Chicken McNuggets(40-piece) in the Chicken & Fish section which also has the highest protein content. They might go for other categories in Salads, Snacks & Slides, or less calorific items in Chicken & Fish, Beef & Pork, etc. or if they have a sweet-tooth, they might go for Desserts or Smoothies & Shakes or Coffee & Tea but would have a high sugar content.

# %% [markdown]
# **INFERENCE:**
#
# **NUTRITIONAL COMPONENTS:**
#
# (I) The frequency to eat calorific foods are in an increasing order from 0 - 250 calories, then it decreases. The only outlier is at 1880 calories. Likewise, for Total Fat, it is in a decreasing order. Similarly for Carbohydrates, the frequency is increasing till 40, and then it steadily decreases.
#
# (II) The food with the highest cholesterol is Big Breakfast with Hotcakes(Regular Biscuit)
#
# (III) The foods with highest Saturated Fats are McFlurry with M&M's Candies (Medium) and Big Breakfast with Hotcakes (Large Biscuit) The average human being should aim for around 56g of protein per day and daily caloric intake is around 2,000 to 2,500 calories per day for women and 2,500 to 3,000 calories per day for men. The more densely populated area is people who have calorie intake of 0-750 while taking protein of 0-50g.
#
# (IV) The average human being should have fat intake of 44-78 grams of fat per day. The most densely populated area is people who have calorie intake between 0-750 and gaining 0-50g of fat per day.
#
# (V) The average sugar intake should be 25 grams (6 teaspoons) of added sugars per day for women and 36 grams (9 teaspoons) for men. This is based on a daily caloric intake of around 2,000 calories. As the number of calories increases until 1000, the sugar level increases till it reaches 130 at 875 calories.

# %% [markdown]
# **RECOMMENDATIONS:**
#
# (I) Caloric Intake: Encourage moderation in caloric intake, focusing on a balanced distribution of calories throughout the day. Be mindful of outliers and extremely high-calorie foods.
#
# (II) Total Fat and Saturated Fats: Emphasize the consumption of healthy fats while minimizing the intake of saturated fats. Choose foods with lower levels of saturated fats.
#
# (III) Cholesterol: Encourage awareness of high-cholesterol food choices and promote balanced eating to manage cholesterol levels.
#
# (IV) Protein Intake: Promote a well-rounded diet that includes adequate protein, aiming for the average recommended intake of around 56g per day.
#
# (V) Sugar Intake: Advocate for mindful consumption of added sugars within recommended limits and encourage awareness of sugar content in foods, especially as caloric intake increases.

# %% [markdown]
# **INFERENCE:**
#
# **NUTRITIONAL COMPONENT VS CATEGORY:**
#
# (I) Smoothies and Shakes have the highest sugar content out of all the food categories. Coffee & Tea is densely populated between 10-70 sugar per day.
#
# (II) Some categories, like Breakfast and Beef & Pork, contain items with extremely high sodium content. Categories like Beverages, Coffee & Tea, and Smoothies & Shakes have very low sodium content, making them better options for those looking to reduce their sodium intake.
#
# (III) The categories "Beef & Pork" and "Chicken & Fish" tend to have the highest protein content, while "Desserts", "Beverages", and "Coffee & Tea" have the lowest.
#
# (IV) Breakfast, Beef & Pork, and Chicken & Fish are the categories with high total fat. Beverages contain least total fat.
#
# (V) Breakfast items have high cholesterol, while beverages have the least.

# %% [markdown]
# **RECOMMENDATIONS:**
#
# (I) Limit the consumption of Smoothies and Shakes due to their high sugar content. When choosing beverages, opt for options in the Coffee & Tea category with lower sugar content (10-70 sugar per day).
#
# (II) Be cautious with categories like Breakfast and Beef & Pork that contain items with high sodium content. Consider selecting options from categories like Beverages, Coffee & Tea, and Smoothies & Shakes, which have lower sodium content to help manage sodium intake.
#
# (III) Ensure a balanced intake of protein by incorporating choices from categories like Beef & Pork and Chicken & Fish, which provide high protein content. For individuals looking to increase protein intake, these categories can be good options.
#
# (IV) Be mindful of the total fat content in Breakfast, Beef & Pork, and Chicken & Fish categories. Opt for items from the Beverages category if you are aiming to reduce total fat intake.
#
# (V) Watch the cholesterol content in Breakfast items and consider moderating intake. Choose beverages as a low-cholesterol option, especially if you are mindful of cholesterol levels in your diet.
